# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-0.26.5.tar.gz (55 kB)
#      ---------------------------------------- 55.5/55.5 kB 3.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-win_amd64.whl (323 kB)
#      -------------------------------------- 323.6/323.6 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in c:\users\hp\anaconda3\lib\site-packages (from openai) (4.64.1)
# Requirement already satisfied: requests>=2.20 in c:\users\hp\anaconda3\lib\site-packages (from openai) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.20->openai) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.20->openai) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.20->openai) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.20->openai) (2.0.4)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-win_amd64.whl (34 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\hp\anaconda3\lib\site-packages (from aiohttp->openai) (21.4.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-win_amd64.whl (56 kB)
#      ---------------------------------------- 56.8/56.8 kB ? eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-win_amd64.whl (28 kB)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from tqdm->openai) (0.4.5)
# Building wheels for collected packages: openai
#   Building wheel for openai (pyproject.toml): started
#   Building wheel for openai (pyproject.toml): finished with status 'done'
#   Created wheel for openai: filename=openai-0.26.5-py3-none-any.whl size=67643 sha256=5f76e18c197bd1aebbbd17d531905844191a5ae1cc254f4e7bfc17476152441b
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\6b\f6\a3\b6f128b03291d3b9c9b70b45ed4cb5ca32021aa4905b67c761
# Successfully built openai
# Installing collected packages: multidict, frozenlist, async-timeout, yarl, aiosignal, aiohttp, openai
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 frozenlist-1.3.3 multidict-6.0.4 openai-0.26.5 yarl-1.8.2

# %%
import openai
import os

# %%
os.environ["OPENAI_API_KEY"] = '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'

# %%
openai.api_key = os.environ["OPENAI_API_KEY"]

# define a function to perform mathematical operations
def calculate(operator, operand1, operand2):
    result = ""
    if operator.lower() == "add":
        result = "sum of {} and {} is {}".format(operand1, operand2, str(float(operand1) + float(operand2)))
    elif operator.lower() == "subtract":
        result = "{} minus {} is {}".format(operand1, operand2, str(float(operand1) - float(operand2)))
    elif operator.lower() == "multiply":
        result = "{} multiplied by {} is {}".format(operand1, operand2, str(float(operand1) * float(operand2)))
    elif operator.lower() == "division":
        if operand2 == "0":
            result = "Can't divide by 0, enter a valid operand"
        else:
            result = "division of {} by {} is {}".format(operand1, operand2, str(float(operand1) / float(operand2)))
    else:
        result = "Sorry, I am not programmed to perform that operation, but I ensure that the next time you are here, you'll find that working!"
    return result

# set up OpenAI GPT-3 API parameters
model_engine = "text-davinci-002"
prompt = "Welcome to MATHEMATICS_ON_BOTS! I can perform basic math operations. Enter 'bye' to exit. \nBot: What mathematical operation do you want to do?\nUser: "

# start chatting with the bot using OpenAI API
while True:
    # get user input
    user_input = input(prompt)
    # check if user wants to exit
    if user_input.lower() == 'bye':
        print("MATHEMATICS_ON_BOTS: SEE YOU UNTIL NEXT TIME!")
        break
    else:
        # check for keywords in user input
        if "what" in user_input.lower() and "operation" in user_input.lower():
            prompt = "MATHEMATICS_ON_BOTS : Kindly choose from the following operations: add, subtract, multiply, division \nUser: "
        elif "sum" in user_input.lower() or "add" in user_input.lower():
            operator = "add"
            prompt = "MATHEMATICS_ON_BOTS : What is the first operand? \nUser: "
            operand1 = input(prompt).strip()
            prompt = "MATHEMATICS_ON_BOTS : What is the second operand? \nUser: "
            operand2 = input(prompt).strip()
            result = calculate(operator, operand1, operand2)
            print("MATHEMATICS_ON_BOTS :", result)
            prompt = "MATHEMATICS_ON_BOTS : What mathematical operation do you want to do next? \nUser: "
        elif "minus" in user_input.lower() or "subtract" in user_input.lower():
            operator = "subtract"
            prompt = "MATHEMATICS_ON_BOTS : What is the first operand? \nUser: "
            operand1 = input(prompt).strip()
            prompt = "MATHEMATICS_ON_BOTS : What is the second operand? \nUser: "
            operand2 = input(prompt).strip()
            result = calculate(operator, operand1, operand2)
            print("MATHEMATICS_ON_BOTS :", result)
            prompt = "MATHEMATICS_ON_BOTS : What mathematical operation do you want to do next? \nUser: "
        elif "multiply" in user_input.lower() or "times" in user_input.lower():
            operator = "multiply"
            prompt = "MATHEMATICS_ON_BOTS : What is the first operand? \nUser: "
            operand1 = input(prompt).strip()
            prompt = "MATHEMATICS_ON_BOTS : What is the second operand? \nUser: "
            operand2 = input(prompt).strip()
            result = calculate(operator, operand1, operand2)
            print("MATHEMATICS_ON_BOTS :", result)
            prompt = "MATHEMATICS_ON_BOTS : What mathematical operation do you want to do next? \nUser: "
        elif "division" in user_input.lower():
            operator = "division"
            prompt = "MATHEMATICS_ON_BOTS : What is the first operand? \nUser: "
            operand1 = input(prompt).strip()
            prompt = "MATHEMATICS_ON_BOTS : What is the second operand? \nUser: "
            operand2 = input(prompt).strip()
            result = calculate(operator, operand1, operand2)
            print("MATHEMATICS_ON_BOTS :", result)
            prompt = "MATHEMATICS_ON_BOTS : What mathematical operation do you want to do next? \nUser: "
        else:
            prompt = "MATHEMATICS_ON_BOTS : Sorry, I didn't understand your input. Please try again or enter 'bye' to exit. \nUser: "
            continue
        
        # generate response using OpenAI API
        prompt += operand1 + "\n"
        response = openai.Completion.create(
            engine=model_engine,
            prompt=prompt,
            max_tokens=1024,
            n=1,
            stop=None,
            temperature=0.5,
        )
        
        # parse OpenAI API response and display result
        bot_response = response.choices[0].text.strip()
        print("MATHEMATICS_ON_BOTS :", bot_response)
